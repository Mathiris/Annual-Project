# %%
import base64
from PIL import Image
from io import BytesIO
import numpy
import sys, os
import cv2
import matplotlib.pyplot as plt

# %%
image = Image.open(' data:image/jpeg;base64,...')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4d4083e6363e> in <module>
# ----> 1 image = Image.open(' data:image/jpeg;base64,...')
#
# c:\users\corin\appdata\local\continuum\miniconda3\envs\tf2gpu\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2764
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#    2768
#
# FileNotFoundError: [Errno 2] No such file or directory: ' data:image/jpeg;base64,...'

# %%
im = Image.open(BytesIO(base64.b64decode(image)))
im.save('image.png', 'PNG')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-3c030c691af1> in <module>
# ----> 1 im = Image.open(BytesIO(base64.b64decode(image)))
#       2 im.save('image.png', 'PNG')
#
# c:\users\corin\appdata\local\continuum\miniconda3\envs\tf2gpu\lib\base64.py in b64decode(s, altchars, validate)
#      78     in the input result in a binascii.Error.
#      79     """
# ---> 80     s = _bytes_from_decode_data(s)
#      81     if altchars is not None:
#      82         altchars = _bytes_from_decode_data(altchars)
#
# c:\users\corin\appdata\local\continuum\miniconda3\envs\tf2gpu\lib\base64.py in _bytes_from_decode_data(s)
#      44     except TypeError:
#      45         raise TypeError("argument should be a bytes-like object or ASCII "
# ---> 46                         "string, not %r" % s.__class__.__name__) from None
#      47
#      48
#
# ...

# %%
img = cv2.imread('Mathias1.png')

# %%
face_model = cv2.CascadeClassifier("haarcascade_frontalface_alt2.xml")

# %%
faces = face_model.detectMultiScale(img)

# %%
if type(faces)is numpy.ndarray :
    print(True)
else :
    print (False)
# Out:
# False

# %%
os.remove('image.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-b366920971b5> in <module>
# ----> 1 os.remove('image.png')
#
# FileNotFoundError: [WinError 2] Le fichier spécifié est introuvable: 'image.png'
